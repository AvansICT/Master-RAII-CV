# %% [markdown]
# # Train YOLO model

# %%
# !pip install ultralytics opencv-python

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
print('Model geladen!')

model.train(
    data="data.yaml",
    epochs=20,
    imgsz=640
)
